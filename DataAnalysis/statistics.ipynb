# %% [markdown]
# # This is statistics session

# %% [markdown]
# Data 2 Types: Quantitative | Qualitative (Categorical)

# %% [markdown]
# statistics 2 types: Descriptive | Inferential (Predictive)

# %% [markdown]
# * Frequent Statistics

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42) # seed for reproducibility means you get the same random numbers each time

# %% [markdown]
# Measures of central Tendency : provides a summary statistic on the center of a given distribution "average value"

# %%
x = st.skewnorm.rvs(10, size=1000)

# %%
x[0:20]
# Out:
# array([0.63349013, 0.04557363, 0.65040763, 1.45109873, 0.1635155 ,
#        0.19382172, 1.66045054, 0.82682805, 0.36271008, 0.48660953,
#        0.33003223, 0.44375653, 0.44725763, 1.97236175, 1.54362254,
#        0.53980414, 1.07262315, 0.26453934, 0.93539347, 1.36308862])

# %%
fig, ax = plt.subplots()
_ = plt.hist(x, color= 'lightgray', bins=50)
