# %% [markdown]
# # Thos is session 4 python

# %% [markdown]
# # Quiz:
# Create a function that takes two numbers as arguments (num, length) and returns a list of multiples of num until the list length reaches length.

# %%
def list_of_multiples(num,length):
    lst=[]
    while len(lst)<length:
        for i in range(1, length + 1):
            lst.append(num*i)
    return lst


list_of_multiples(7, 5)
# Out:
# [7, 14, 21, 28, 35]

# %% [markdown]
# # Modules:
# are Python files containing functions and variables that u can import the module to use it in another file using keyword: "import"
#
# # note:
#  u can't see and import from module if it is not in same folder with the file u will use the module in
#
# # steps:
# 1) create a file with the module name u want with extension .py ->ex: utils.py
# 2) use one of the 2 following methods to import from the module
#
# # import 2 methods:
# 1) import module_name
# 2) from module_name import function_name_inside_module
# 3) u can easier to import all functions in a module say: from utils import *

# %%
#Method 1 to import from module:
import utils

utils.list_of_multiples(7, 5)
# Out:
# [7, 14, 21, 28, 35]

# %%
#Method 2 to import from module:
from utils import list_of_multiples

list_of_multiples(7,5)
# Out:
# [7, 14, 21, 28, 35]

# %% [markdown]
# # Packages:
# is a collection of modules stored in a directory , a directory becomes a package by including the special file __init__.py
#
# # note: (pypi-> python package index) is a repository of open-source python packages
#
# # steps:
# 1) create a new folder   ex: helpers
# 2) add a module to it    ex: utils
# 3) create an empty __init__.py  file to make it a package
#
# # import steps:
# 1)

# %%
# in case u have modules in another folder u should it its path
import sys
print(sys.path)
sys.path.append("D:\\IBM Data Scienctist DEPI\\DEPI_Projects\\Python")
# Out:
# ['c:\\Users\\fxrxh\\miniconda3\\python313.zip', 'c:\\Users\\fxrxh\\miniconda3\\DLLs', 'c:\\Users\\fxrxh\\miniconda3\\Lib', 'c:\\Users\\fxrxh\\miniconda3', '', 'c:\\Users\\fxrxh\\miniconda3\\Lib\\site-packages', 'c:\\Users\\fxrxh\\miniconda3\\Lib\\site-packages\\win32', 'c:\\Users\\fxrxh\\miniconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\fxrxh\\miniconda3\\Lib\\site-packages\\Pythonwin', 'D:\\IBM Data Scienctist DEPI\\DEPI_Projects\\Python']

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.1

# %% [markdown]
# # DataFrame as a data structure from pandas package

# %%
data = pd.DataFrame(
    {
        "Name":["Farah","Mohamed"],
        "Age":[30,24]
    }
)

print(data)
# Out:
#       Name  Age
# 0    Farah   30
# 1  Mohamed   24

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Age     2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes

# %%
data.describe()
# Out:
#              Age
# count   2.000000
# mean   27.000000
# std     4.242641
# min    24.000000
# 25%    25.500000
# 50%    27.000000
# 75%    28.500000
# max    30.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris_data = pd.read_csv("iris.csv")
print(iris_data.head())

print("===========")

print(iris_data.info())

print("===========")

# Scatter plot: Sepal length vs Sepal width
plt.scatter(iris_data['SepalLengthCm'], iris_data['SepalWidthCm'], color='green')
plt.title("Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.show()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# ...

# %% [markdown]
# # Object Oriented Programming
