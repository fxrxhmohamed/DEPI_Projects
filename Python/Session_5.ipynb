# %% [markdown]
# # This is session 5 oop in python

# %% [markdown]
# # Constructor creatin example: Calculator

# %%
class calculator:
    def __init__(self,x,y):
        print("A calculator have been created!")
        self.x=x
        self.y=y
    def add(self):
        return self.x + self.y
    
    def substract(self):
        return self.x - self.y
    
    def multiply(self):
        return self.x * self.y

    def divide(self):
        return self.x / self.y

c = calculator(4,2)
print(c.add())
print(c.substract())
print(c.multiply())
print(c.divide())
# Out:
# A calculator have been created!
# 6
# 2
# 8
# 2.0

# %% [markdown]
# # Inheritance

# %%
class pet():
    def __init__(self,name,color,voice):
        self.name=name
        self.color=color
        self.voice=voice
    def speak(self):
        print(self.voice,"...",self.voice)

class cat(pet):
    def __init__(self,name,color):
        super().__init__(name,color,"Meow")

class dog(pet):
    def __init__(self,name,color):
        super().__init__(name,color,"Woof")

tom = cat("Tom","Grey")
tom.speak()
roy=dog("Roy","Black")
roy.speak()
# Out:
# Meow ... Meow
# Woof ... Woof

# %% [markdown]
# # Task
# Add to the Country class so that it contains the attribute is_big. Set it to True if either criterion are met:
# Population is greater than 250 million.
# Area is larger than 3 million square km.
# Also, create a method which compares a country’s population density to another country object

# %%
class Country():
    def __init__(self,name,population,area):
        self.name = name
        self.population=population
        self.area=area

    def is_big(self):
        if self.population > 250000000 or self.area > 3000000:
            return True
        else:
            return False
        
    def compare_pd(self,other):
        self_density = self.population / self.area
        other_density = other.population / other.area

        if self_density > other_density:
            return f"{self.name} has a larger population density than {other.name}"

        elif self_density < other_density:
            return f"{other.name} has a larger population density than {self.name}"
        else:
            return f"{other.name} has a larger population density than {self.name}"
        
australia = Country("Australia", 260000000,30)
print(australia.is_big())

egypt = Country("Egypt",250,35000000)
print(egypt.is_big())

turkie = Country("Turkie",250,35000000)
print(turkie.is_big())

japan = Country("Japan",250,30)
print(japan.is_big())

print(japan.compare_pd(egypt))
print(turkie.compare_pd(egypt))
# Out:
# True
# True
# True
# False
# Japan has a larger population density than Egypt
# Egypt has a larger population density than Turkie

# %% [markdown]
# # Abstraction

# %% [markdown]
# # 3 Access Modifiers:
# -> Public attribute:     self.balance
# -> Protected attribute:  self._balance
# -> Private attribute:    self.__balance

# %%
# each attribute/method in a class have 3 levels of abstraction (access modifiers)
# 1) public: "don't have any underscores before attribute name" normal attributes can be accessed from inside/outside the class and can be inherited
# 2) protected: "will has 1 underscore before attribute name" attribute/method that should not be accessed outside the class visible 
# 3) private: "will have 2 underscores before the attribute" attribute/method can't be access from outside the class and class not visible 
# Q) what is the use of the private modifier? ->  restrict access to class attributes or methods from outside the class.which helps keep internal class details hidden and protected. u can access this attributes using setters and getters

#Solution 1

class pet():
    def __init__(self,name,color,voice):
        self.name=name #publiv attribute
        self.color=color
        self.voice=voice

        self._A1 = "Protected"
        self.__A2 = "Private"
    def speak(self):
        print(self.voice,"...",self.voice)

class cat(pet):
    def __init__(self,name,color,voice):
        super().__init__(name,color,voice)

class dog(pet):
    def __init__(self,name,color,voice):
        super().__init__(name,color,voice)
        

    
tom = cat("Tom","Grey","Meow")
tom.speak()
roy=dog("Roy","Black","Woof")
roy.speak()

print(tom._A1)
# print(tom.__A2)  # will raise this error "cat' object has no attribute '__A2'"  as __A2 is private can't be accessed without setters & getters

# in the coming code will resolve this problem using setters and getters....
# Out:
# Meow ... Meow
# Woof ... Woof
# Protected

# %%
#Solution 2
class pet():
    def __init__(self,name,color,voice):
        self.name=name #public attribute
        self.color=color
        self.voice=voice

        self._A1 = "Protected"
        self.__A2 = "Private"
    def speak(self):
        print(self.voice,"...",self.voice)
    def get_A2(self):
        # getter for private attribute , this allows controlled access to the private attribute __A2
        return self.__A2
    def set_A2(self,value):
        if isinstance(value,str):
            self.__A2=value
        else:
            print("Value must be a string")
        
class cat(pet):
    def __init__(self,name,color):
        super().__init__(name,color,"Meow")

class dog(pet):
    def __init__(self,name,color):
        super().__init__(name,color,"Woof")

    
tom = cat("Tom","Grey")
tom.speak()
roy=dog("Roy","Black")
roy.speak()

print(tom._A1)
print(tom.get_A2())
# Out:
# Meow ... Meow
# Woof ... Woof
# Protected
# Private

# %% [markdown]
# # Abstraction example

# %%
from abc import ABC, abstractmethod

#Abstract classes provide a blueprint for other classes.
#They cannot be instantiated directly and require subclasses to implement abstract methods.
class Vehicle(ABC):
   @abstractmethod
   def start_engine(self):
       pass

class Car(Vehicle):
    def start_engine(self):
       print("Car engine started.")

class Bike(Vehicle):
     def start_engine(self):
        print("Bike engine started.")

#The following line would raise an error:
#v = Vehicle() # TypeError: Can't instantiate abstract class Vehicle with abstract method start_engine
car = Car()
bike = Bike()
car.start_engine()
bike.start_engine()
# Out:
# Car engine started.
# Bike engine started.

# %% [markdown]
# # Polymorphism  :
# meaning "many forms"
# Polymorphism allows us to use the same method name or interface,but have different implementations depending on the object that is calling it.

# %% [markdown]
# # Overloading Vs. Overriding
# -> Overloading:
# * In the method overloading, inheritance may or may not be required.
# * Method overloading is performed between methods within the class.
# -> Overriding:
# * Whereas in method overriding, inheritance always required.
# * Whereas method overriding is done between parent class and child class methods.

# %%
# ABC stands for Abstract Base Class 
# -> abstractbaseclass: It allows us to define a template for other classes
# -> abstractmethod: is a decorator that marks a method as abstract must be implemented in any subclass or python will raise an error

from abc import ABC, abstractmethod

class Shape:
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self): #this is called polymprphism as circle implements the area method defined in shape
        return 3.14 * self.radius ** 2

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side ** 2

shapes = [Circle(5), Square(4)]
for shape in shapes:
    print(shape.area())
# calls the area method of each shape, demonstrating polymorphism
# Out:
# 78.5
# 16

# %%
from abc import ABC, abstractmethod

class shape:
    @abstractmethod
    def area(self):
        pass

class circle(shape):
    def __init__(self,r):
        self.r=r
    def area(self):
        return 2* 3.14 * self.r
class square(shape):
    def __init__(self,l):
        self.l=l
    def area(self):
        return self.l ** 2

s1 = circle(3)
s1.area()

s = [circle(5),square(4)]
for x in s :
    print(x.area())
# Out:
# 31.400000000000002
# 16

# %% [markdown]
# # Operator Overloading:
# operators have special methods, there default law m3mltsh override lehom will raise errors !!

# %%
# ay special method gwa class btbd2 w tentehe be double underscore, ex: __init__, __str__

class Vector:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    # da operator overloading using speacial method "__str__" byt7km fl representation bt3 el class 
    # ,mngheero haytb3 no3 el object wl address bta3o kdh: "<__main__.Vector object at 0x000001EAA3D3FE00>""
    def __str__(self):
        return "("+str(self.x)+","+str(self.y)+")"
    
    def __add__(self,other): # operator overloading for the '+' operator
        if isinstance(other,Vector):
            return Vector(self.x+other.x,self.y+other.y)
        else:
            raise TypeError("Operand must be an instance of vector")

V1 = Vector(2,3)
print(V1)

V2 = Vector(4,5)
print(V2)

print(V1+V2)
# Out:
# (2,3)
# (4,5)
# (6,8)

# %% [markdown]
# # This code demonstrates method overriding in Python. Class B inherits from class A and overrides the fun1() method. When fun1() is called on an instance of B, the overridden method in class B is executed instead of the original method in class A.

# %%
class A:

    def fun1(self):
        print('feature_1 of class A')
        
    def fun2(self):
        print('feature_2 of class A')
    
class B(A):
    
    # Modified function that already exist in class A
    def fun1(self):
        print('Modified feature_1 of class A by class B')    
        
    def fun3(self):
        print('feature_3 of class B')
        
        
# Create instance
obj = B()
    
# Call the override function
obj.fun1()

obj2 = A()
obj2.fun1()
# Out:
# Modified feature_1 of class A by class B
# feature_1 of class A
